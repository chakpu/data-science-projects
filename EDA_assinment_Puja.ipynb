# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# reading data files
Loan=pd.read_csv("loan.csv",dtype='unicode')

# %%
Loan.head(20)
# Out:
#          id member_id loan_amnt funded_amnt funded_amnt_inv        term  \
# 0   1077501   1296599      5000        5000            4975   36 months
# 1   1077430   1314167      2500        2500            2500   60 months
# 2   1077175   1313524      2400        2400            2400   36 months
# 3   1076863   1277178     10000       10000           10000   36 months
# 4   1075358   1311748      3000        3000            3000   60 months
# 5   1075269   1311441      5000        5000            5000   36 months
# 6   1069639   1304742      7000        7000            7000   60 months
# 7   1072053   1288686      3000        3000            3000   36 months
# 8   1071795   1306957      5600        5600            5600   60 months
# 9   1071570   1306721      5375        5375            5350   60 months
# 10  1070078   1305201      6500        6500            6500   60 months
# 11  1069908   1305008     12000       12000           12000   36 months
# ...

# %%
Loan.tail(20)
# Out:
#            id member_id loan_amnt funded_amnt funded_amnt_inv        term  \
# 39697  101579    100083     10000       10000             400   36 months
# 39698   98982     98957      5000        5000             675   36 months
# 39699   98339     97572      5100        5100             575   36 months
# 39700   98276     98268      5400        5400             200   36 months
# 39701   96844     95222      5300        5300             600   36 months
# 39702   96350     96338      5000        5000             850   36 months
# 39703   94838     73673      3000        3000            2550   36 months
# 39704   93277     93254      3000        3000             950   36 months
# 39705   93061     93057      5000        5000             250   36 months
# 39706   92676     92671      5000        5000             150   36 months
# 39707   92666     92661      5000        5000             525   36 months
# 39708   92552     92542      5000        5000             375   36 months
# ...

# %%
# look at the Loan df info for number of rows etc.
Loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: object(111)
# memory usage: 33.6+ MB

# %%
Loan.shape
# Out:
# (39717, 111)

# %%
Loan.describe()
# Out:
#             id member_id loan_amnt funded_amnt funded_amnt_inv        term  \
# count    39717     39717     39717       39717           39717       39717
# unique   39717     39717       885        1041            8205           2
# top     492241    716272     10000       10000            5000   36 months
# freq         1         1      2833        2741            1309       29096
#
#        int_rate installment  grade sub_grade            ...              \
# count     39717       39717  39717     39717            ...
# unique      371       15383      7        35            ...
# top      10.99%      311.11      B        B3            ...
# freq        956          68  12020      2917            ...
#
#        num_tl_90g_dpd_24m num_tl_op_past_12m pct_tl_nvr_dlq percent_bc_gt_75  \
# count                 0.0                0.0            0.0              0.0
# unique                0.0                0.0            0.0              0.0
# ...

# %%
#check unique ids#
Loan['id'].unique()

#check unique memberids
Loan['id'].nunique()
# Out:
# 39717

# %%
#check unique memberids

Loan['member_id'].unique()

#check unique count memberids
Loan['member_id'].nunique()
# Out:
# 39717

# %%
# make sure that number of duplicate rows are zero
sum(Loan.duplicated(subset = 'id')) == 0
# Out:
# True

# %%
# make sure that number of duplicate rows are zero
sum(Loan.duplicated(subset = 'member_id')) == 0
# Out:
# True

# %% [markdown]
# # check for NA values in dataset

# %%
Loan.isnull().sum()
# Out:
# id                                    0
# member_id                             0
# loan_amnt                             0
# funded_amnt                           0
# funded_amnt_inv                       0
# term                                  0
# int_rate                              0
# installment                           0
# grade                                 0
# sub_grade                             0
# emp_title                          2459
# emp_length                         1075
# home_ownership                        0
# annual_inc                            0
# verification_status                   0
# issue_d                               0
# loan_status                           0
# pymnt_plan                            0
# url                                   0
# desc                              12940
# purpose                               0
# title                                11
# zip_code                              0
# ...

# %%
Loan.isnull().sum()*100/Loan.shape[0]
# Out:
# id                                  0.000000
# member_id                           0.000000
# loan_amnt                           0.000000
# funded_amnt                         0.000000
# funded_amnt_inv                     0.000000
# term                                0.000000
# int_rate                            0.000000
# installment                         0.000000
# grade                               0.000000
# sub_grade                           0.000000
# emp_title                           6.191303
# emp_length                          2.706650
# home_ownership                      0.000000
# annual_inc                          0.000000
# verification_status                 0.000000
# issue_d                             0.000000
# loan_status                         0.000000
# pymnt_plan                          0.000000
# url                                 0.000000
# desc                               32.580507
# purpose                             0.000000
# ...

# %% [markdown]
# ##There are number of columns where all the row has Null values.So deleating all those coloumns##

# %% [markdown]
# # DROP Unnecesery coloumns

# %%
##There are number of columns where all the row has Null values.So deleating all those coloumns##

Loan=Loan.drop(['mo_sin_old_rev_tl_op',            
'mo_sin_rcnt_rev_tl_op',             
'mo_sin_rcnt_tl',                     
'mort_acc',                           
'mths_since_recent_bc',               
'mths_since_recent_bc_dlq',           
'mths_since_recent_inq',              
'mths_since_recent_revol_delinq',     
'num_accts_ever_120_pd',
'num_actv_bc_tl',                     
'num_actv_rev_tl',                    
'num_bc_sats',                     
'num_bc_tl',                          
'num_il_tl',                       
'num_op_rev_tl',                   
'num_rev_accts',                      
'num_rev_tl_bal_gt_0',                
'num_sats',                           
'num_tl_120dpd_2m',                   
'num_tl_30dpd',                       
'num_tl_90g_dpd_24m',                 
'num_tl_op_past_12m',                 
'pct_tl_nvr_dlq',                     
'percent_bc_gt_75'], axis = 1)

# %%
Loan.shape
# Out:
# (39717, 87)

# %%
Loan.isnull().sum()
# Out:
# id                                0
# member_id                         0
# loan_amnt                         0
# funded_amnt                       0
# funded_amnt_inv                   0
# term                              0
# int_rate                          0
# installment                       0
# grade                             0
# sub_grade                         0
# emp_title                      2459
# emp_length                     1075
# home_ownership                    0
# annual_inc                        0
# verification_status               0
# issue_d                           0
# loan_status                       0
# pymnt_plan                        0
# url                               0
# desc                          12940
# purpose                           0
# title                            11
# zip_code                          0
# addr_state                        0
# dti                               0
# delinq_2yrs                       0
# ...

# %%
##PART2:Delete columns where all the row has Null values.##

Loan=Loan.drop(['tot_coll_amt',
'tot_cur_bal',
'open_acc_6m',                  
'open_il_6m',                    
'open_il_12m',                  
'open_il_24m',                 
'mths_since_rcnt_il',  
'total_bal_il',
'il_util',                       
'open_rv_12m',                   
'open_rv_24m',                   
'max_bal_bc',                    
'all_util',                      
'total_rev_hi_lim',              
'inq_fi',                        
'total_cu_tl',                   
'inq_last_12m',                  
'acc_open_past_24mths',          
'avg_cur_bal',                   
'bc_open_to_buy',                
'bc_util'],axis=1)

# %%
Loan.shape
# Out:
# (39717, 66)

# %%
Loan.isnull().sum()
# Out:
# id                                 0
# member_id                          0
# loan_amnt                          0
# funded_amnt                        0
# funded_amnt_inv                    0
# term                               0
# int_rate                           0
# installment                        0
# grade                              0
# sub_grade                          0
# emp_title                       2459
# emp_length                      1075
# home_ownership                     0
# annual_inc                         0
# verification_status                0
# issue_d                            0
# loan_status                        0
# pymnt_plan                         0
# url                                0
# desc                           12940
# purpose                            0
# title                             11
# zip_code                           0
# addr_state                         0
# dti                                0
# ...

# %%
##PART3:Delete columns where all the row has Null values##

Loan=Loan.drop(['mths_since_last_major_derog','annual_inc_joint','dti_joint','verification_status_joint','mo_sin_old_il_acct','tot_hi_cred_lim','total_bal_ex_mort','total_bc_limit','total_il_high_credit_limit'],axis=1)

# %%
Loan.shape
# Out:
# (39717, 57)

# %%
Loan.isnull().sum()
# Out:
# id                                0
# member_id                         0
# loan_amnt                         0
# funded_amnt                       0
# funded_amnt_inv                   0
# term                              0
# int_rate                          0
# installment                       0
# grade                             0
# sub_grade                         0
# emp_title                      2459
# emp_length                     1075
# home_ownership                    0
# annual_inc                        0
# verification_status               0
# issue_d                           0
# loan_status                       0
# pymnt_plan                        0
# url                               0
# desc                          12940
# purpose                           0
# title                            11
# zip_code                          0
# addr_state                        0
# dti                               0
# delinq_2yrs                       0
# ...

# %%
# Inspecting the percentages of Null values again
round(Loan.isnull().sum()*100/Loan.shape[0],2)
# Out:
# id                             0.00
# member_id                      0.00
# loan_amnt                      0.00
# funded_amnt                    0.00
# funded_amnt_inv                0.00
# term                           0.00
# int_rate                       0.00
# installment                    0.00
# grade                          0.00
# sub_grade                      0.00
# emp_title                      6.19
# emp_length                     2.71
# home_ownership                 0.00
# annual_inc                     0.00
# verification_status            0.00
# issue_d                        0.00
# loan_status                    0.00
# pymnt_plan                     0.00
# url                            0.00
# desc                          32.58
# purpose                        0.00
# title                          0.03
# zip_code                       0.00
# addr_state                     0.00
# dti                            0.00
# delinq_2yrs                    0.00
# ...

# %% [markdown]
# here coloumns next_pymnt_d,mths_since_last_record have more than 90% null
# value.

# %%
# removing rows having 90% null records
Loan=Loan.drop(['next_pymnt_d','mths_since_last_record'],axis=1)

# %%
round(Loan.isnull().sum()*100/Loan.shape[0],2)
# Out:
# id                             0.00
# member_id                      0.00
# loan_amnt                      0.00
# funded_amnt                    0.00
# funded_amnt_inv                0.00
# term                           0.00
# int_rate                       0.00
# installment                    0.00
# grade                          0.00
# sub_grade                      0.00
# emp_title                      6.19
# emp_length                     2.71
# home_ownership                 0.00
# annual_inc                     0.00
# verification_status            0.00
# issue_d                        0.00
# loan_status                    0.00
# pymnt_plan                     0.00
# url                            0.00
# desc                          32.58
# purpose                        0.00
# title                          0.03
# zip_code                       0.00
# addr_state                     0.00
# dti                            0.00
# delinq_2yrs                    0.00
# ...

# %%
Loan.describe()
# Out:
#             id member_id loan_amnt funded_amnt funded_amnt_inv        term  \
# count    39717     39717     39717       39717           39717       39717
# unique   39717     39717       885        1041            8205           2
# top     492241    716272     10000       10000            5000   36 months
# freq         1         1      2833        2741            1309       29096
#
#        int_rate installment  grade sub_grade    ...    last_pymnt_amnt  \
# count     39717       39717  39717     39717    ...              39717
# unique      371       15383      7        35    ...              34930
# top      10.99%      311.11      B        B3    ...                  0
# freq        956          68  12020      2917    ...                 74
#
#        last_credit_pull_d collections_12_mths_ex_med policy_code  \
# count               39715                      39661       39717
# unique                106                          1           1
# ...

# %% [markdown]
# From above description we can see  below coloumns have unique value and some of them also have missing values.
# 'collections_12_mths_ex_med','policy_code','application_type','acc_now_delinq','chargeoff_within_12_mths','delinq_amnt','tax_liens'

# %%
##Check the unique value##
Loan['collections_12_mths_ex_med'].unique()
# Out:
# array(['0', nan], dtype=object)

# %%
Loan['policy_code'].unique()
# Out:
# array(['1'], dtype=object)

# %%
Loan['application_type'].unique()
# Out:
# array(['INDIVIDUAL'], dtype=object)

# %%
Loan['acc_now_delinq'].unique()
# Out:
# array(['0'], dtype=object)

# %%
Loan['chargeoff_within_12_mths'].unique()
# Out:
# array(['0', nan], dtype=object)

# %%
Loan['delinq_amnt'].unique()
# Out:
# array(['0'], dtype=object)

# %%
Loan['tax_liens'].unique()
# Out:
# array(['0', nan], dtype=object)

# %%
##Delete coloumns having unique value##
Loan=Loan.drop(['collections_12_mths_ex_med','policy_code','application_type','acc_now_delinq','chargeoff_within_12_mths','delinq_amnt','tax_liens'],axis=1)

# %%
Loan.shape
# Out:
# (39717, 48)

# %%
round(Loan.isnull().sum()*100/Loan.shape[0],2)
# Out:
# id                          0.00
# member_id                   0.00
# loan_amnt                   0.00
# funded_amnt                 0.00
# funded_amnt_inv             0.00
# term                        0.00
# int_rate                    0.00
# installment                 0.00
# grade                       0.00
# sub_grade                   0.00
# emp_title                   6.19
# emp_length                  2.71
# home_ownership              0.00
# annual_inc                  0.00
# verification_status         0.00
# issue_d                     0.00
# loan_status                 0.00
# pymnt_plan                  0.00
# url                         0.00
# desc                       32.58
# purpose                     0.00
# title                       0.03
# zip_code                    0.00
# addr_state                  0.00
# dti                         0.00
# delinq_2yrs                 0.00
# earliest_cr_line            0.00
# inq_last_6mths              0.00
# ...

# %% [markdown]
# 1.For finding defaulter below coloumns are not so informative:
#     coloumns: URL ,desc,title,
# 2.Also we can delete mths_since_last_delinq as this coloumn contain more than 60% null.
# 3.last_pymnt_d  ,last_pymnt_amnt won't help us to identify if the customer will be defsulter or not
# 4.sub_grade — contains redundant information that is already in the grade column (more below).
# 5.ID.Member id also not related with deafult customer
# 6.Grade can tell us about int_rate.So we can delete this coloumn.

# %%
Loan=Loan.drop(['url','desc','title','pymnt_plan','initial_list_status','mths_since_last_delinq','last_pymnt_d','last_pymnt_amnt','sub_grade','id','member_id','int_rate'],axis=1)

# %%
Loan.shape
# Out:
# (39717, 36)

# %%
Loan.describe()
# Out:
#        loan_amnt funded_amnt funded_amnt_inv        term installment  grade  \
# count      39717       39717           39717       39717       39717  39717
# unique       885        1041            8205           2       15383      7
# top        10000       10000            5000   36 months      311.11      B
# freq        2833        2741            1309       29096          68  12020
#
#        emp_title emp_length home_ownership annual_inc         ...           \
# count      37258      38642          39717      39717         ...
# unique     28820         11              5       5318         ...
# top      US Army  10+ years           RENT      60000         ...
# freq         134       8879          18899       1505         ...
#
#        out_prncp_inv  total_pymnt total_pymnt_inv total_rec_prncp  \
# count          39717        39717           39717           39717
# unique          1138        37850           37518            7976
# ...

# %%
round(Loan.isnull().sum()*100/Loan.shape[0],2)
# Out:
# loan_amnt                  0.00
# funded_amnt                0.00
# funded_amnt_inv            0.00
# term                       0.00
# installment                0.00
# grade                      0.00
# emp_title                  6.19
# emp_length                 2.71
# home_ownership             0.00
# annual_inc                 0.00
# verification_status        0.00
# issue_d                    0.00
# loan_status                0.00
# purpose                    0.00
# zip_code                   0.00
# addr_state                 0.00
# dti                        0.00
# delinq_2yrs                0.00
# earliest_cr_line           0.00
# inq_last_6mths             0.00
# open_acc                   0.00
# pub_rec                    0.00
# revol_bal                  0.00
# revol_util                 0.13
# total_acc                  0.00
# out_prncp                  0.00
# out_prncp_inv              0.00
# total_pymnt                0.00
# total_pymnt_inv            0.00
# ...

# %%
## Change emp_title into lower Case
Loan['emp_title'] = Loan['emp_title'].str.lower()
Loan.head()
# Out:
#   loan_amnt funded_amnt funded_amnt_inv        term installment grade  \
# 0      5000        5000            4975   36 months      162.87     B
# 1      2500        2500            2500   60 months       59.83     C
# 2      2400        2400            2400   36 months       84.33     C
# 3     10000       10000           10000   36 months      339.31     C
# 4      3000        3000            3000   60 months       67.79     B
#
#                   emp_title emp_length home_ownership annual_inc  \
# 0                       NaN  10+ years           RENT      24000
# 1                     ryder   < 1 year           RENT      30000
# 2                       NaN  10+ years           RENT      12252
# 3       air resources board  10+ years           RENT      49200
# 4  university medical group     1 year           RENT      80000
#
#           ...          out_prncp_inv  total_pymnt total_pymnt_inv  \
# 0         ...                      0  5863.155187         5833.84
# ...

# %%
Loan.tail()
# Out:
#       loan_amnt funded_amnt funded_amnt_inv        term installment grade  \
# 39712      2500        2500            1075   36 months       78.42     A
# 39713      8500        8500             875   36 months      275.38     C
# 39714      5000        5000            1325   36 months      156.84     A
# 39715      5000        5000             650   36 months      155.38     A
# 39716      7500        7500             800   36 months      255.43     E
#
#                         emp_title emp_length home_ownership annual_inc  \
# 39712             fisite research    4 years       MORTGAGE     110000
# 39713  squarewave solutions, ltd.    3 years           RENT      18000
# 39714                         NaN   < 1 year       MORTGAGE      1e+05
# 39715                         NaN   < 1 year       MORTGAGE      2e+05
# 39716            evergreen center   < 1 year            OWN      22000
#
#               ...          out_prncp_inv  total_pymnt total_pymnt_inv  \
# ...

# %% [markdown]
# Cleaning Is Done

# %% [markdown]
# # Univariate Analysis

# %%
# Now let's filter the df so it only contains the past default customers value

Loan_chargeoff=Loan[(Loan.loan_status=='Charged Off')]

# %%
Loan_chargeoff.head()
# Out:
#    loan_amnt funded_amnt funded_amnt_inv        term installment grade  \
# 1       2500        2500            2500   60 months       59.83     C
# 8       5600        5600            5600   60 months      152.39     F
# 9       5375        5375            5350   60 months      121.45     B
# 12      9000        9000            9000   36 months      305.38     C
# 14     10000       10000           10000   36 months      325.74     B
#
#                               emp_title emp_length home_ownership annual_inc  \
# 1                                 ryder   < 1 year           RENT      30000
# 8                                   NaN    4 years            OWN      40000
# 9                             starbucks   < 1 year           RENT      15000
# 12  va. dept of conservation/recreation   < 1 year           RENT      30000
# 14                                sfmta    3 years           RENT      1e+05
#
#            ...          out_prncp_inv total_pymnt total_pymnt_inv  \
# ...

# %%
round(100*Loan_chargeoff.groupby('addr_state').size()/len(Loan_chargeoff),2).reset_index(name="percent").sort_values('percent',ascending=False)
# Out:
#    addr_state  percent
# 4          CA    19.99
# 9          FL     8.96
# 30         NY     8.80
# 39         TX     5.62
# 27         NJ     4.94
# 10         GA     3.82
# 13         IL     3.50
# 34         PA     3.20
# 41         VA     3.15
# 18         MD     2.88
# 17         MA     2.83
# 31         OH     2.75
# 43         WA     2.26
# 3          AZ     2.19
# 21         MO     2.03
# 24         NC     2.03
# 29         NV     1.92
# 19         MI     1.83
# 5          CO     1.74
# 6          CT     1.67
# 20         MN     1.44
# 33         OR     1.26
# 36         SC     1.17
# 44         WI     1.12
# 1          AL     0.96
# 16         LA     0.94
# 15         KY     0.80
# 40         UT     0.71
# 32         OK     0.71
# 14         KS     0.55
# 28         NM     0.53
# 11         HI     0.50
# 2          AR     0.48
# 35         RI     0.44
# 26         NH     0.44
# 45         WV     0.37
# 7          DC     0.27
# 0          AK     0.27
# 8          DE     0.21
# ...

# %%
#1.Grade and Default

sns.countplot(x="grade", data=Loan_chargeoff)

# %%
##2 term and Default
sns.countplot(x="term", data=Loan_chargeoff)

# %%
##.Purpose and Default
sns.countplot(y="purpose", data=Loan_chargeoff)

# %%
##4.Employ lenth and Default
sns.countplot(y="emp_length", data=Loan_chargeoff)

# %%
sns.countplot(x="pub_rec_bankruptcies",data=Loan_chargeoff)

# %%
####5.home_ownership lenth and Default
sns.countplot(x="home_ownership",data=Loan_chargeoff)

# %%
####6.verification_status lenth and Default

sns.countplot(x="verification_status",data=Loan_chargeoff)

# %% [markdown]
# # Bivariate

# %%
##Home ownership vs Loans status
sns.countplot(x="home_ownership",hue="loan_status", data=Loan)

# %% [markdown]
# Observation: Count is high for customer having home status Rent.

# %%
##Home ownership vs Loans status
sns.countplot(x="verification_status",hue="loan_status", data=Loan)

# %%
##term vs Loans status
sns.countplot(x="term",hue="loan_status", data=Loan)

# %%
sns.countplot(y="emp_length",hue="loan_status", data=Loan)

# %%
sns.countplot(y="purpose",hue="loan_status", data=Loan)

# %%
x=Loan['loan_amnt']
y=Loan['annual_inc']
plt.scatter(x, y,alpha=0.5)
plt.show()
